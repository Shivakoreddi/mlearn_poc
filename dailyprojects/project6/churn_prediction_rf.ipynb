# %%
import pandas as pd
import numpy as np
from scipy.stats import ks_2samp
np.random.seed(42)

# %%
df = pd.read_csv("/Users/shiva/Downloads/churn_user_features.csv")
df.info(memory_usage='deep')
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              10000 non-null  int64
#  1   user_id                 10000 non-null  object
#  2   age                     10000 non-null  int64
#  3   region                  10000 non-null  object
#  4   device_type             10000 non-null  object
#  5   current_tenure          10000 non-null  int64
#  6   time_to_renewal         10000 non-null  int64
#  7   promo_flag              10000 non-null  bool
#  8   total_hours_streamed    10000 non-null  float64
#  9   avg_session_length      10000 non-null  float64
#  10  avg_startup_latency     10000 non-null  float64
#  11  p95_startup_latency     10000 non-null  float64
#  12  total_rebuffers         10000 non-null  int64
#  13  rebuffers_per_session   10000 non-null  float64
#  14  avg_throughput          10000 non-null  float64
#  15  slow_throughput_rate    10000 non-null  float64
#  16  avg_jitter              10000 non-null  float64
#  17  month_hours_streamed    10000 non-null  float64
#  18  month_session_count     10000 non-null  int64
#  19  usage_trend_slope       10000 non-null  float64
#  20  ticket_count            10000 non-null  int64
#  21  days_since_last_ticket  3945 non-null   float64
# dtypes: bool(1), float64(11), int64(7), object(3)
# memory usage: 2.9 MB
# (10000, 22)

# %%
df.describe()
# Out:
#         Unnamed: 0           age  current_tenure  time_to_renewal  \
# count  10000.00000  10000.000000    10000.000000     10000.000000
# mean    4999.50000     44.021700      194.882000       -90.607700
# std     2886.89568     15.203998       97.217962       105.751336
# min        0.00000     18.000000       30.000000      -333.000000
# 25%     2499.75000     31.000000      111.000000      -174.000000
# 50%     4999.50000     44.000000      194.000000       -90.000000
# 75%     7499.25000     57.000000      278.000000        -7.000000
# max     9999.00000     70.000000      364.000000       144.000000
#
#        total_hours_streamed  avg_session_length  avg_startup_latency  \
# count          10000.000000        10000.000000         10000.000000
# mean              10.004899            1.745234           551.054162
# std                7.077026            0.727252           258.016198
# min                0.068293            0.500365           100.251654
# 25%                4.831897            1.115773           329.782699
# 50%                8.378878            1.734848           550.146066
# 75%               13.391402            2.382010           773.246005
# max               58.590612            2.999732           999.733113
#
#        p95_startup_latency  total_rebuffers  rebuffers_per_session  \
# count         10000.000000     10000.000000           10000.000000
# mean            650.954050         2.004800               1.488886
# std             264.366532         1.421682               0.864787
# min             108.950956         0.000000               0.000007
# 25%             428.515932         1.000000               0.742734
# 50%             651.479629         2.000000               1.478008
# 75%             871.151982         3.000000               2.223322
# max            1196.823829        10.000000               2.999807
#
#        avg_throughput  slow_throughput_rate    avg_jitter  \
# count    10000.000000          10000.000000  10000.000000
# mean         5.493334              0.504703    106.169214
# std          2.590829              0.289830     54.684132
# min          1.001808              0.000018     10.002074
# 25%          3.259962              0.251836     59.372482
# 50%          5.476932              0.505851    106.968069
# 75%          7.768558              0.755832    153.666978
# max          9.998971              0.999984    199.992585
#
#        month_hours_streamed  month_session_count  usage_trend_slope  \
# count          10000.000000         10000.000000       10000.000000
# mean              20.007668            24.926700          -0.055471
# std               14.270783            14.219668           2.897946
# min                0.103298             1.000000          -4.999513
# 25%                9.599375            13.000000          -2.610195
# 50%               16.778718            25.000000          -0.046222
# 75%               26.948818            37.000000           2.473903
# max              119.161297            49.000000           4.999750
#
#        ticket_count  days_since_last_ticket
# count  10000.000000             3945.000000
# mean       0.505200               30.213942
# std        0.715698               17.178040
# min        0.000000                1.000000
# 25%        0.000000               15.000000
# 50%        0.000000               30.000000
# 75%        1.000000               45.000000
# max        5.000000               59.000000

# %%
##Predict whether a customer will churn (leave) next month
df.head(5)
# Out:
#    Unnamed: 0 user_id  age region device_type  current_tenure  \
# 0           0  U00001   56     US      mobile             356
# 1           1  U00002   69     EU    smart_tv             296
# 2           2  U00003   46     US      mobile             299
# 3           3  U00004   32  LATAM      mobile             157
# 4           4  U00005   60    MEA      tablet             293
#
#    time_to_renewal  promo_flag  total_hours_streamed  avg_session_length  ...  \
# 0             -231       False              8.644639            2.705790  ...
# 1             -140       False              3.677074            2.365369  ...
# 2             -209       False              8.039530            0.547339  ...
# 3              -54       False              4.930183            2.524625  ...
# 4             -232       False              7.194304            0.567824  ...
#
#    total_rebuffers  rebuffers_per_session  avg_throughput  \
# 0                5               1.426019        8.120058
# 1                3               2.218157        1.790549
# 2                3               2.708621        1.700032
# 3                2               1.920391        4.740932
# 4                1               2.259991        8.673750
#
#    slow_throughput_rate  avg_jitter  month_hours_streamed  \
# 0              0.948775  194.134075              6.875991
# 1              0.314351   66.308197             23.163118
# 2              0.228268  129.994075             46.165920
# 3              0.902906  162.650231             16.303295
# 4              0.500406   24.976007             30.194688
#
#    month_session_count  usage_trend_slope  ticket_count  \
# 0                   45           1.066576             1
# 1                    3           4.633615             0
# 2                    6           1.414259             0
# 3                   15          -2.275332             0
# 4                   22          -2.600993             0
#
#    days_since_last_ticket
# 0                     4.0
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 22 columns]

# %%
##dataframe memory optimization

float_cols = df.select_dtypes(include=['float64']).columns
int_cols = df.select_dtypes(include=['int64']).columns

df[float_cols] = df[float_cols].astype('float32')
df[int_cols] = df[int_cols].astype('int32')

print("Memory optimization of column types:")
df.info(memory_usage='deep')
# Out:
# Memory optimization of column types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              10000 non-null  int32
#  1   user_id                 10000 non-null  object
#  2   age                     10000 non-null  int32
#  3   region                  10000 non-null  object
#  4   device_type             10000 non-null  object
#  5   current_tenure          10000 non-null  int32
#  6   time_to_renewal         10000 non-null  int32
#  7   promo_flag              10000 non-null  bool
#  8   total_hours_streamed    10000 non-null  float32
#  9   avg_session_length      10000 non-null  float32
#  10  avg_startup_latency     10000 non-null  float32
#  11  p95_startup_latency     10000 non-null  float32
#  12  total_rebuffers         10000 non-null  int32
#  13  rebuffers_per_session   10000 non-null  float32
#  14  avg_throughput          10000 non-null  float32
#  15  slow_throughput_rate    10000 non-null  float32
#  16  avg_jitter              10000 non-null  float32
#  17  month_hours_streamed    10000 non-null  float32
#  18  month_session_count     10000 non-null  int32
#  19  usage_trend_slope       10000 non-null  float32
#  20  ticket_count            10000 non-null  int32
#  21  days_since_last_ticket  3945 non-null   float32
# dtypes: bool(1), float32(11), int32(7), object(3)
# memory usage: 2.3 MB

# %%
##Parse transaction timestamp and derive features
##Dop unecessary ID/PII columns - Purpose: Remove columns that leak information or have no predictive value. 
##Why: IDs and PII add noise or risk leakage but rarely generalize.


# df.drop(columns=['customerID','PaperlessBilling'],inplace=True)
# df.columns
# df.info(memory_usage='deep')

# %%
# Drop card number, transaction ID, personal identifiers
df.drop(columns=['Unnamed: 0'], inplace=True)

# Preview remaining columns
df.columns
# Out:
# Index(['user_id', 'age', 'region', 'device_type', 'current_tenure',
#        'time_to_renewal', 'promo_flag', 'total_hours_streamed',
#        'avg_session_length', 'avg_startup_latency', 'p95_startup_latency',
#        'total_rebuffers', 'rebuffers_per_session', 'avg_throughput',
#        'slow_throughput_rate', 'avg_jitter', 'month_hours_streamed',
#        'month_session_count', 'usage_trend_slope', 'ticket_count',
#        'days_since_last_ticket'],
#       dtype='object')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 10000 non-null  object
#  1   age                     10000 non-null  int32
#  2   region                  10000 non-null  object
#  3   device_type             10000 non-null  object
#  4   current_tenure          10000 non-null  int32
#  5   time_to_renewal         10000 non-null  int32
#  6   promo_flag              10000 non-null  bool
#  7   total_hours_streamed    10000 non-null  float32
#  8   avg_session_length      10000 non-null  float32
#  9   avg_startup_latency     10000 non-null  float32
#  10  p95_startup_latency     10000 non-null  float32
#  11  total_rebuffers         10000 non-null  int32
#  12  rebuffers_per_session   10000 non-null  float32
#  13  avg_throughput          10000 non-null  float32
#  14  slow_throughput_rate    10000 non-null  float32
#  15  avg_jitter              10000 non-null  float32
#  16  month_hours_streamed    10000 non-null  float32
#  17  month_session_count     10000 non-null  int32
#  18  usage_trend_slope       10000 non-null  float32
#  19  ticket_count            10000 non-null  int32
#  20  days_since_last_ticket  3945 non-null   float32
# dtypes: bool(1), float32(11), int32(6), object(3)
# memory usage: 2.2 MB

# %%
df.head(5)
# Out:
#   user_id  age region device_type  current_tenure  time_to_renewal  \
# 0  U00001   56     US      mobile             356             -231
# 1  U00002   69     EU    smart_tv             296             -140
# 2  U00003   46     US      mobile             299             -209
# 3  U00004   32  LATAM      mobile             157              -54
# 4  U00005   60    MEA      tablet             293             -232
#
#    promo_flag  total_hours_streamed  avg_session_length  avg_startup_latency  \
# 0       False              8.644639            2.705790           752.148376
# 1       False              3.677074            2.365369           638.462219
# 2       False              8.039530            0.547339           367.117706
# 3       False              4.930182            2.524625           290.034729
# 4       False              7.194304            0.567824           361.935791
#
#    ...  total_rebuffers  rebuffers_per_session  avg_throughput  \
# 0  ...                5               1.426019        8.120058
# 1  ...                3               2.218158        1.790549
# 2  ...                3               2.708621        1.700032
# 3  ...                2               1.920391        4.740932
# 4  ...                1               2.259990        8.673750
#
#    slow_throughput_rate  avg_jitter  month_hours_streamed  \
# 0              0.948775  194.134079              6.875990
# 1              0.314351   66.308197             23.163118
# 2              0.228268  129.994080             46.165920
# 3              0.902906  162.650238             16.303295
# 4              0.500406   24.976007             30.194689
#
#    month_session_count  usage_trend_slope  ticket_count  \
# 0                   45           1.066576             1
# 1                    3           4.633615             0
# 2                    6           1.414259             0
# 3                   15          -2.275332             0
# 4                   22          -2.600992             0
#
#    days_since_last_ticket
# 0                     4.0
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 21 columns]

# %%
##Calculate the formula for churn

##define rules - 
##1. when user  

df['churn_label'] = ((df['time_to_renewal'] >= 0) &
                     (df['time_to_renewal'] <= 30)).astype(int)

# %%
df.head(5)
# Out:
#   user_id  age region device_type  current_tenure  time_to_renewal  \
# 0  U00001   56     US      mobile             356             -231
# 1  U00002   69     EU    smart_tv             296             -140
# 2  U00003   46     US      mobile             299             -209
# 3  U00004   32  LATAM      mobile             157              -54
# 4  U00005   60    MEA      tablet             293             -232
#
#    promo_flag  total_hours_streamed  avg_session_length  avg_startup_latency  \
# 0       False              8.644639            2.705790           752.148376
# 1       False              3.677074            2.365369           638.462219
# 2       False              8.039530            0.547339           367.117706
# 3       False              4.930182            2.524625           290.034729
# 4       False              7.194304            0.567824           361.935791
#
#    ...  rebuffers_per_session  avg_throughput  slow_throughput_rate  \
# 0  ...               1.426019        8.120058              0.948775
# 1  ...               2.218158        1.790549              0.314351
# 2  ...               2.708621        1.700032              0.228268
# 3  ...               1.920391        4.740932              0.902906
# 4  ...               2.259990        8.673750              0.500406
#
#    avg_jitter  month_hours_streamed  month_session_count  usage_trend_slope  \
# 0  194.134079              6.875990                   45           1.066576
# 1   66.308197             23.163118                    3           4.633615
# 2  129.994080             46.165920                    6           1.414259
# 3  162.650238             16.303295                   15          -2.275332
# 4   24.976007             30.194689                   22          -2.600992
#
#    ticket_count  days_since_last_ticket  churn_label
# 0             1                     4.0            0
# 1             0                     NaN            0
# 2             0                     NaN            0
# 3             0                     NaN            0
# 4             0                     NaN            0
#
# [5 rows x 22 columns]

# %%
# Fraction of fraud cases
fraud_ratio = df['churn_label'].mean()
print(f"churn fraction: {fraud_ratio:.6f} ({fraud_ratio*100:.3f}% )")
df['churn_label'].value_counts()
# Out:
# churn fraction: 0.085600 (8.560% )
# churn_label
# 0    9144
# 1     856
# Name: count, dtype: int64

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 10000 non-null  object
#  1   age                     10000 non-null  int32
#  2   region                  10000 non-null  object
#  3   device_type             10000 non-null  object
#  4   current_tenure          10000 non-null  int32
#  5   time_to_renewal         10000 non-null  int32
#  6   promo_flag              10000 non-null  bool
#  7   total_hours_streamed    10000 non-null  float32
#  8   avg_session_length      10000 non-null  float32
#  9   avg_startup_latency     10000 non-null  float32
#  10  p95_startup_latency     10000 non-null  float32
#  11  total_rebuffers         10000 non-null  int32
#  12  rebuffers_per_session   10000 non-null  float32
#  13  avg_throughput          10000 non-null  float32
#  14  slow_throughput_rate    10000 non-null  float32
#  15  avg_jitter              10000 non-null  float32
#  16  month_hours_streamed    10000 non-null  float32
#  17  month_session_count     10000 non-null  int32
#  18  usage_trend_slope       10000 non-null  float32
#  19  ticket_count            10000 non-null  int32
#  20  days_since_last_ticket  3945 non-null   float32
#  21  churn_label             10000 non-null  int64
# dtypes: bool(1), float32(11), int32(6), int64(1), object(3)
# memory usage: 2.3 MB

# %%
missing_pct = df.isna().mean().sort_values(ascending=False)
print(missing_pct[missing_pct>0])
# Out:
# days_since_last_ticket    0.6055
# dtype: float64

# %%
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols].nunique().sort_values(ascending=False)
# Out:
# user_id        10000
# region             5
# device_type        4
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                           count unique     top  freq        mean         std  \
# user_id                   10000  10000  U00001     1         NaN         NaN
# age                     10000.0    NaN     NaN   NaN     44.0217   15.203998
# region                    10000      5      EU  2056         NaN         NaN
# device_type               10000      4  tablet  2548         NaN         NaN
# current_tenure          10000.0    NaN     NaN   NaN     194.882   97.217962
# time_to_renewal         10000.0    NaN     NaN   NaN    -90.6077  105.751336
# promo_flag                10000      2   False  7038         NaN         NaN
# total_hours_streamed    10000.0    NaN     NaN   NaN   10.004899    7.077026
# avg_session_length      10000.0    NaN     NaN   NaN    1.745234    0.727252
# avg_startup_latency     10000.0    NaN     NaN   NaN  551.054138  258.016205
# p95_startup_latency     10000.0    NaN     NaN   NaN  650.953979  264.366547
# total_rebuffers         10000.0    NaN     NaN   NaN      2.0048    1.421682
# rebuffers_per_session   10000.0    NaN     NaN   NaN    1.488886    0.864787
# avg_throughput          10000.0    NaN     NaN   NaN    5.493334    2.590829
# slow_throughput_rate    10000.0    NaN     NaN   NaN    0.504703     0.28983
# avg_jitter              10000.0    NaN     NaN   NaN  106.169212   54.684132
# month_hours_streamed    10000.0    NaN     NaN   NaN   20.007669   14.270783
# month_session_count     10000.0    NaN     NaN   NaN     24.9267   14.219668
# usage_trend_slope       10000.0    NaN     NaN   NaN   -0.055471    2.897946
# ticket_count            10000.0    NaN     NaN   NaN      0.5052    0.715698
# days_since_last_ticket   3945.0    NaN     NaN   NaN   30.213942    17.17804
# churn_label             10000.0    NaN     NaN   NaN      0.0856    0.279786
#
#                                min         25%         50%         75%  \
# user_id                        NaN         NaN         NaN         NaN
# age                           18.0        31.0        44.0        57.0
# region                         NaN         NaN         NaN         NaN
# device_type                    NaN         NaN         NaN         NaN
# current_tenure                30.0       111.0       194.0       278.0
# time_to_renewal             -333.0      -174.0       -90.0        -7.0
# promo_flag                     NaN         NaN         NaN         NaN
# total_hours_streamed      0.068293    4.831897    8.378878   13.391402
# avg_session_length        0.500365    1.115773    1.734848     2.38201
# avg_startup_latency     100.251656  329.782692  550.146088  773.246017
# p95_startup_latency     108.950958  428.515923  651.479614  871.151993
# total_rebuffers                0.0         1.0         2.0         3.0
# rebuffers_per_session     0.000007    0.742734    1.478008    2.223322
# avg_throughput            1.001808    3.259962    5.476932    7.768558
# slow_throughput_rate      0.000018    0.251836    0.505851    0.755832
# avg_jitter               10.002073   59.372483  106.968067  153.666973
# month_hours_streamed      0.103298    9.599376   16.778718   26.948818
# month_session_count            1.0        13.0        25.0        37.0
# usage_trend_slope        -4.999513   -2.610195   -0.046222    2.473903
# ticket_count                   0.0         0.0         0.0         1.0
# days_since_last_ticket         1.0        15.0        30.0        45.0
# churn_label                    0.0         0.0         0.0         0.0
#
#                                 max
# user_id                         NaN
# age                            70.0
# region                          NaN
# device_type                     NaN
# current_tenure                364.0
# time_to_renewal               144.0
# promo_flag                      NaN
# total_hours_streamed      58.590611
# avg_session_length         2.999732
# avg_startup_latency      999.733093
# p95_startup_latency     1196.823853
# total_rebuffers                10.0
# rebuffers_per_session      2.999807
# avg_throughput             9.998971
# slow_throughput_rate       0.999984
# avg_jitter               199.992584
# month_hours_streamed     119.161293
# month_session_count            49.0
# usage_trend_slope           4.99975
# ticket_count                    5.0
# days_since_last_ticket         59.0
# churn_label                     1.0

# %%
# Class counts & ratios
counts = df['churn_label'].value_counts()
ratios = df['churn_label'].value_counts(normalize=True)
print(pd.concat([counts, ratios], axis=1, keys=['count','ratio']))
# Out:
#              count   ratio
# churn_label
# 0             9144  0.9144
# 1              856  0.0856

# %%
# Only select numeric columns for correlation
num_cols = df.select_dtypes(include=['number']).columns

# Compute correlations with 'is_fraud'
num_corr = df[num_cols].corr()['churn_label'].abs().sort_values(ascending=False)

print("Top numeric correlations with churn_label:")
print(num_corr.head(10))
# Out:
# Top numeric correlations with churn_label:
# churn_label              1.000000
# current_tenure           0.308914
# time_to_renewal          0.303332
# total_rebuffers          0.018075
# avg_jitter               0.016897
# age                      0.012470
# month_hours_streamed     0.012293
# total_hours_streamed     0.011993
# rebuffers_per_session    0.007801
# ticket_count             0.007266
# Name: churn_label, dtype: float64

# %%
##Leakage checks

# ✅ Only use numeric columns for correlation
# numeric_cols = df.select_dtypes(include=['int32']).columns
# num_corr = df[numeric_cols].corr()['Churn'].abs().sort_values(ascending=False)

# print("Top numeric correlations:")
# print(num_corr.head(10))

cat_cols = df.select_dtypes(include=['object']).columns

for col in cat_cols:
    try:
        if df.groupby(col)['churn_label'].nunique().eq(1).all():
            print(f"⚠️ Potential leakage in '{col}' — perfect predictor")
    except Exception as e:
        print(f"Could not evaluate column {col}: {e}")
# Out:
# ⚠️ Potential leakage in 'user_id' — perfect predictor

# %%
dup_count = df.duplicated().sum()
print(f"Duplicate rows: {dup_count}")
if dup_count > 0:
    df.drop_duplicates(inplace=True)
    print("Duplicates dropped")
# Out:
# Duplicate rows: 0

# %%
import pyarrow
df.to_parquet(r'/Users/shiva/Downloads/churn_prediction_cleaned.parquet', index=False)
print("Cleaned data saved to 'churn_prediction_cleaned.parquet'")
# Out:
# Cleaned data saved to 'churn_prediction_cleaned.parquet'

# %%
##Feature engineering steps
df = pd.read_parquet('/Users/shiva/Downloads/churn_prediction_cleaned.parquet')

# %%
df.info(memory_usage='deep')

cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols].nunique().sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 10000 non-null  object
#  1   age                     10000 non-null  int32
#  2   region                  10000 non-null  object
#  3   device_type             10000 non-null  object
#  4   current_tenure          10000 non-null  int32
#  5   time_to_renewal         10000 non-null  int32
#  6   promo_flag              10000 non-null  bool
#  7   total_hours_streamed    10000 non-null  float32
#  8   avg_session_length      10000 non-null  float32
#  9   avg_startup_latency     10000 non-null  float32
#  10  p95_startup_latency     10000 non-null  float32
#  11  total_rebuffers         10000 non-null  int32
#  12  rebuffers_per_session   10000 non-null  float32
#  13  avg_throughput          10000 non-null  float32
#  14  slow_throughput_rate    10000 non-null  float32
#  15  avg_jitter              10000 non-null  float32
#  16  month_hours_streamed    10000 non-null  float32
#  17  month_session_count     10000 non-null  int32
#  18  usage_trend_slope       10000 non-null  float32
#  19  ticket_count            10000 non-null  int32
#  20  days_since_last_ticket  3945 non-null   float32
#  21  churn_label             10000 non-null  int64
# dtypes: bool(1), float32(11), int32(6), int64(1), object(3)
# memory usage: 2.3 MB
# user_id        10000
# region             5
# device_type        4
# dtype: int64

# %%
##Encoding categorical variables
from sklearn.preprocessing import LabelEncoder

df.columns

# columns you want to label‑encode → new column name
ENCODE_MAP = {
    "user_id":         "userid"
    # "region":          "region_all",
    # "device_type":     "devicetype"# map label → final target
}

encoders = {}                      # (optional) keep fitted encoders

for col, new_col in ENCODE_MAP.items():
    if col in df.columns:
        le = LabelEncoder()
        df[new_col] = le.fit_transform(df[col])
        encoders[col] = le          # store for inverse‑transform / inference
        df.drop(columns=[col], inplace=True)
df.head(5)
# Out:
#    age region device_type  current_tenure  time_to_renewal  promo_flag  \
# 0   56     US      mobile             356             -231       False
# 1   69     EU    smart_tv             296             -140       False
# 2   46     US      mobile             299             -209       False
# 3   32  LATAM      mobile             157              -54       False
# 4   60    MEA      tablet             293             -232       False
#
#    total_hours_streamed  avg_session_length  avg_startup_latency  \
# 0              8.644639            2.705790           752.148376
# 1              3.677074            2.365369           638.462219
# 2              8.039530            0.547339           367.117706
# 3              4.930182            2.524625           290.034729
# 4              7.194304            0.567824           361.935791
#
#    p95_startup_latency  ...  avg_throughput  slow_throughput_rate  avg_jitter  \
# 0           864.831909  ...        8.120058              0.948775  194.134079
# 1           754.223267  ...        1.790549              0.314351   66.308197
# 2           463.690247  ...        1.700032              0.228268  129.994080
# 3           317.688934  ...        4.740932              0.902906  162.650238
# 4           416.324799  ...        8.673750              0.500406   24.976007
#
#    month_hours_streamed  month_session_count  usage_trend_slope  ticket_count  \
# 0              6.875990                   45           1.066576             1
# 1             23.163118                    3           4.633615             0
# 2             46.165920                    6           1.414259             0
# 3             16.303295                   15          -2.275332             0
# 4             30.194689                   22          -2.600992             0
#
#    days_since_last_ticket  churn_label  userid
# 0                     4.0            0       0
# 1                     NaN            0       1
# 2                     NaN            0       2
# 3                     NaN            0       3
# 4                     NaN            0       4
#
# [5 rows x 22 columns]

# %%
df = pd.concat([df, pd.get_dummies(df['device_type'], prefix='cat', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df['region'], prefix='cat', drop_first=True)], axis=1)
df.drop(columns=['region','device_type'], inplace=True)
df.head(5)


# cat_cols = df.select_dtypes(include=['object']).columns
# df[cat_cols].nunique().sort_values(ascending=False)
# Out:
#    age  current_tenure  time_to_renewal  promo_flag  total_hours_streamed  \
# 0   56             356             -231       False              8.644639
# 1   69             296             -140       False              3.677074
# 2   46             299             -209       False              8.039530
# 3   32             157              -54       False              4.930182
# 4   60             293             -232       False              7.194304
#
#    avg_session_length  avg_startup_latency  p95_startup_latency  \
# 0            2.705790           752.148376           864.831909
# 1            2.365369           638.462219           754.223267
# 2            0.547339           367.117706           463.690247
# 3            2.524625           290.034729           317.688934
# 4            0.567824           361.935791           416.324799
#
#    total_rebuffers  rebuffers_per_session  ...  days_since_last_ticket  \
# 0                5               1.426019  ...                     4.0
# 1                3               2.218158  ...                     NaN
# 2                3               2.708621  ...                     NaN
# 3                2               1.920391  ...                     NaN
# 4                1               2.259990  ...                     NaN
#
#    churn_label  userid  cat_mobile  cat_smart_tv  cat_tablet  cat_EU  \
# 0            0       0        True         False       False   False
# 1            0       1       False          True       False    True
# 2            0       2        True         False       False   False
# 3            0       3        True         False       False   False
# 4            0       4       False         False        True   False
#
#    cat_LATAM  cat_MEA  cat_US
# 0      False    False    True
# 1      False    False   False
# 2      False    False    True
# 3       True    False   False
# 4      False     True   False
#
# [5 rows x 27 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     10000 non-null  int32
#  1   current_tenure          10000 non-null  int32
#  2   time_to_renewal         10000 non-null  int32
#  3   promo_flag              10000 non-null  bool
#  4   total_hours_streamed    10000 non-null  float32
#  5   avg_session_length      10000 non-null  float32
#  6   avg_startup_latency     10000 non-null  float32
#  7   p95_startup_latency     10000 non-null  float32
#  8   total_rebuffers         10000 non-null  int32
#  9   rebuffers_per_session   10000 non-null  float32
#  10  avg_throughput          10000 non-null  float32
#  11  slow_throughput_rate    10000 non-null  float32
#  12  avg_jitter              10000 non-null  float32
#  13  month_hours_streamed    10000 non-null  float32
#  14  month_session_count     10000 non-null  int32
#  15  usage_trend_slope       10000 non-null  float32
#  16  ticket_count            10000 non-null  int32
#  17  days_since_last_ticket  3945 non-null   float32
#  18  churn_label             10000 non-null  int64
#  19  userid                  10000 non-null  int64
#  20  cat_mobile              10000 non-null  bool
#  21  cat_smart_tv            10000 non-null  bool
#  22  cat_tablet              10000 non-null  bool
#  23  cat_EU                  10000 non-null  bool
#  24  cat_LATAM               10000 non-null  bool
#  25  cat_MEA                 10000 non-null  bool
#  26  cat_US                  10000 non-null  bool
# dtypes: bool(8), float32(11), int32(6), int64(2)
# memory usage: 898.6 KB

# %%
##Log Transform skewed numeric features

import numpy as np

# 1. Identify your numeric columns
numeric_cols = df.select_dtypes(include='number').columns

# 2. Compute skewness
skewness = df[numeric_cols].skew()
# # Log transform amount
# df['mnthCharges_log'] = np.log1p(df['MonthlyCharges'])
# df.drop(columns=['MonthlyCharges'], inplace=True)

# # Check skew
# print("Skewness mnthCharges_log:", df['mnthCharges_log'].skew())

# %%
high_skew = skewness[skewness>1]
for col in high_skew.index:
    df[f"{col}_log"] = np.log1p(df[col])

# %%
# df[[f"{col}_log" for col in high_skew.index]].skew()
df.head(5)
# Out:
#    age  current_tenure  time_to_renewal  promo_flag  total_hours_streamed  \
# 0   56             356             -231       False              8.644639
# 1   69             296             -140       False              3.677074
# 2   46             299             -209       False              8.039530
# 3   32             157              -54       False              4.930182
# 4   60             293             -232       False              7.194304
#
#    avg_session_length  avg_startup_latency  p95_startup_latency  \
# 0            2.705790           752.148376           864.831909
# 1            2.365369           638.462219           754.223267
# 2            0.547339           367.117706           463.690247
# 3            2.524625           290.034729           317.688934
# 4            0.567824           361.935791           416.324799
#
#    total_rebuffers  rebuffers_per_session  ...  cat_smart_tv  cat_tablet  \
# 0                5               1.426019  ...         False       False
# 1                3               2.218158  ...          True       False
# 2                3               2.708621  ...         False       False
# 3                2               1.920391  ...         False       False
# 4                1               2.259990  ...         False        True
#
#    cat_EU  cat_LATAM  cat_MEA  cat_US  total_hours_streamed_log  \
# 0   False      False    False    True                  2.266402
# 1    True      False    False   False                  1.542673
# 2   False      False    False    True                  2.201607
# 3   False       True    False   False                  1.780055
# 4   False      False     True   False                  2.103439
#
#    month_hours_streamed_log  ticket_count_log  churn_label_log
# 0                  2.063819          0.693147              0.0
# 1                  3.184827          0.000000              0.0
# 2                  3.853672          0.000000              0.0
# 3                  2.850897          0.000000              0.0
# 4                  3.440248          0.000000              0.0
#
# [5 rows x 31 columns]

# %%
##Final Feature Matrix
df = df.rename(columns={"churn": "churn_label"})
# Drop any remaining raw columns if needed
# Prepare X and y
import numpy as np
# Keep only numeric columns
X = df.drop(columns=['churn_label_log'])

# X.select_dtypes(exclude=['number']).columns
# Fill missing or problematic values
X = X.fillna(0)
X = X.replace([np.inf, -np.inf], 0)

# Confirm shape and types
print(X.dtypes)
print(X.shape)



# X = df.drop(columns=['trans_ts','is_fraud','lat','long','merch_lat','merch_long','dob'])
# y = df['is_fraud']
print("Final feature matrix shape:", X.shape)
print("Features:", X.columns.tolist())
# Out:
# age                           int32
# current_tenure                int32
# time_to_renewal               int32
# promo_flag                     bool
# total_hours_streamed        float32
# avg_session_length          float32
# avg_startup_latency         float32
# p95_startup_latency         float32
# total_rebuffers               int32
# rebuffers_per_session       float32
# avg_throughput              float32
# slow_throughput_rate        float32
# avg_jitter                  float32
# month_hours_streamed        float32
# month_session_count           int32
# usage_trend_slope           float32
# ticket_count                  int32
# days_since_last_ticket      float32
# churn_label                   int64
# userid                        int64
# cat_mobile                     bool
# cat_smart_tv                   bool
# cat_tablet                     bool
# cat_EU                         bool
# cat_LATAM                      bool
# cat_MEA                        bool
# cat_US                         bool
# total_hours_streamed_log    float32
# month_hours_streamed_log    float32
# ticket_count_log            float64
# dtype: object
# (10000, 30)
# Final feature matrix shape: (10000, 30)
# Features: ['age', 'current_tenure', 'time_to_renewal', 'promo_flag', 'total_hours_streamed', 'avg_session_length', 'avg_startup_latency', 'p95_startup_latency', 'total_rebuffers', 'rebuffers_per_session', 'avg_throughput', 'slow_throughput_rate', 'avg_jitter', 'month_hours_streamed', 'month_session_count', 'usage_trend_slope', 'ticket_count', 'days_since_last_ticket', 'churn_label', 'userid', 'cat_mobile', 'cat_smart_tv', 'cat_tablet', 'cat_EU', 'cat_LATAM', 'cat_MEA', 'cat_US', 'total_hours_streamed_log', 'month_hours_streamed_log', 'ticket_count_log']

# %%
df.to_parquet(r'/Users/shiva/Downloads/churn_prediction_cleaned_featured.parquet', index=False)
print("Featured data saved to 'churn_prediction_cleaned_featured.parquet'")
# Out:
# Featured data saved to 'churn_prediction_cleaned_featured.parquet'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split


df = pd.read_parquet(r'/Users/shiva/Downloads/churn_prediction_cleaned_featured.parquet')
X = df.drop(columns=['churn_label'])
y = df['churn_label']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)
print(X_train.shape, X_test.shape, y_train.mean())
# Out:
# (8000, 30) (2000, 30) 0.085625

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline   # imbalanced‑learn wrapper

# ───────────────────────────────────────────────────────────
# 1.  Feature‑type splits
num_cols = X.select_dtypes(include=['int64','float64']).columns
cat_cols = X.select_dtypes(include='object').columns

numeric_pipe = Pipeline([
    ('impute', SimpleImputer(strategy='median')),
    ('scale',  StandardScaler())
])
categorical_pipe = Pipeline([
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('ohe',    OneHotEncoder(handle_unknown='ignore'))
])

preproc = ColumnTransformer([
    ('num', numeric_pipe, num_cols),
    ('cat', categorical_pipe, cat_cols)
])


# ───────────────────────────────────────────────────────────
# 2.  Full pipeline:  Impute/Encode  →  SMOTE  →  RandomForest
rf_pipe = ImbPipeline([
    ('pre',   preproc),
    ('smote', SMOTE(random_state=42)),
    ('clf',   RandomForestClassifier(
                  n_estimators=400,
                  max_depth=None,
                  min_samples_leaf=2,
                  class_weight='balanced',   # handles remaining imbalance
                  random_state=42,
                  n_jobs=-1
    ))
])
from sklearn.metrics import classification_report, roc_auc_score,average_precision_score
# Example fit / evaluate
rf_pipe.fit(X_train, y_train)
y_pred   = rf_pipe.predict(X_test)
y_proba  = rf_pipe.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred, digits=3))
print("ROC‑AUC:", roc_auc_score(y_test, y_proba).round(3))

from sklearn.metrics import classification_report, roc_auc_score,average_precision_score

##validate
# rf_pipe.fit(X_train, y_train)        # should run without NaN error
print("AP:", average_precision_score(y_test, rf_pipe.predict_proba(X_test)[:,1]))

ap = average_precision_score(y_test, y_proba)
print("Average Precision (PR‑AUC):", round(ap, 3))
# Out:
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000      1829
#            1      1.000     1.000     1.000       171
#
#     accuracy                          1.000      2000
#    macro avg      1.000     1.000     1.000      2000
# weighted avg      1.000     1.000     1.000      2000
#
# ROC‑AUC: 1.0
# AP: 1.0
# Average Precision (PR‑AUC): 1.0
